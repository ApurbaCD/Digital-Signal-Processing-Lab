# %%
import numpy as np
import matplotlib.pyplot as plt

t=np.arange(1,10,1)
n=np.linspace(1,10,10)

plt.plot(n)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,100,1000)
y=np.arange(0,10,0.1)
a=np.sin(x)
plt.xlabel("time")
plt.ylabel("value")
plt.grid(True)
plt.plot(a)
plt.show()
