# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(-10,20)

unit_step=np.where(x>=0 , 1 , 0)

unit_ramp=np.where(x>=0 , n , 0)

a=0.9; 
expo=(a**x)*unit_step

omwga=np.pi/8
sine_wave=np.sin(omega*x)

cosine_wave=np.cos(omega*x)


plt.figure(figsize=(20, 20)) #	Start a large canvas for many plots(figsize=(14, 10) means: Width = 14 inches,Height = 10 inches)

plt.subplot(3,2,1) #Create 1 of 6 plots in a 3×2 layout(plt.subplot(rows, columns, position))

# plt.grid(True)
# plt.xlabel("X")
# plt.ylabel("Y")
plt.title("Unit sample u[n]")
# plt.axis([-10,20,-1,2])
plt.stem(x,unit_step)
# plt.show();



plt.subplot(3,2,2)
# plt.grid(True)
plt.title("Unit ramp r[n]")
# plt.axis([-10,20,-1,25])
plt.stem(x,unit_ramp)
# plt.show();

# For expo 

plt.subplot(3,2,3)
# plt.grid(True)
plt.title("Exponential signal")
# plt.axis([-10,20,-1,25])
plt.stem(x,expo)
# plt.show();






plt.subplot(3,2,4)
# plt.grid(True)
plt.title("Sine Sequence: sin(πn/8)")
# plt.axis([-10,20,-1,25])
plt.stem(x,sine_wave)
# plt.show();


plt.subplot(3,2,5)
# plt.grid(True)
plt.title("Cosine Sequence: cos(πn/8)")
# plt.axis([-10,20,-1,25])
plt.stem(x,cosine_wave)
plt.show();

# %%
# ✅ 1. Unit Step Signal u[n]u[n]
# u[n]={1,n≥0
#       0,n<0
#     }

# ✅ 2. Unit Ramp Signal r[n]=n⋅u[n]
# r[n]={n,n≥0
#       0,n<0
#     }

# ✅ 3. Exponential Signal x[n]=an⋅u[n]

#     Growing if a>1

#     Decaying if 0<a<1

# ✅ 4. Sine and Cosine Sequences
# x[n]=sin⁡ (ωn),x[n]=cos⁡(ωn)
# x[n]=sin(ωn),x[n]=cos(ωn)

# Where ω is the angular frequency in radians/sample
